# %% [markdown]
# # Chemical simulation interface
# This notebook provides an interface for a toy model of a chemical reaction in the gas phase.

# %% [markdown]
# ## Import libraries

# %%
from collider import Simulation
from ipycanvas import Canvas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from collider import Simulation
#       2 from ipycanvas import Canvas
#
# File ~/DSA101/collider/collider.py:1
# ----> 1 import numpy as np
#       2 import time
#       3 from dataclasses import dataclass
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## Initialize and run the simulation
# Initialize the Simulation class with the desired parameters and run the simulation loop.

# %%
simulation = Simulation(Canvas, 800, 600, 100, temperature=100)
simulation.canvas(size=(100, 100))

# %%
simulation.run()

# %% [markdown]
# In small groups, assign one task to each person:
# 1. Add live charts that update as the simulation runs and show the current values of the following parameters: temperature, number of collisions, number of reactions, amounts of "product"
# 2. Add different versions of the toy model's "reaction vessel": a wall in the middle, walls with holes.
# 3. Change the simulation such that the reaction products can disassociate again.

# %%
import collider

# %%
def number_of_collisons(slef,simulation):
    count = 0
    if ChemialsphereChemicalSphere.check_sphere_collisions(simulation) == True:
        count += 1
    return count

# %%
number_of_collisons(simulation)
