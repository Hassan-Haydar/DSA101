# %% [markdown]
# # Python syntax review

# %%
a = 5
b = 4

a != b
# Out:
# True

# %%
a = 5
b = 5

a is b
# Out:
# True

# %%
id(a)
# Out:
# 4300859880

# %%
id(b)
# Out:
# 4300859880

# %%
a = 55224752874
b = 55224752874
a is b
# Out:
# False

# %%
ar = [1,2,3,4]
ar[-1]
# Out:
# 4

# %%
ar[::-1]
# Out:
# [4, 3, 2, 1]

# %%
a = 5
b = 4

a + b
# Out:
# 9

# %%
a = "5" 
b = "4"

a + b
# Out:
# '54'

# %%
if a:
    print("what?")
# Out:
# what?

# %%
a = 1
b = 1E-17
a + b == a
# Out:
# True

# %%
type(a)
# Out:
# int

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'is_integer',
#  'numerator',
#  'real',
#  'to_bytes']

# %% [markdown]
# # Review of some Python basics
#
# **Key point: (almost) everything in Python is an object!**

# %% [markdown]
# ## Key functions and concepts:
# ````
# if
# else
# elif
# ````
#
# ````
# for
# while
# ````
#
# ````
# def
# return
# ````
#
# ````
# class
# ````
#
# ````
# import
# ````
#
# ## Exceptions
# ````
# except
# raise
# try
# ````

# %% [markdown]
# ## if, elif, else, conditions
# ````
# if condition:
#     do_something()
# elif other_condition:
#     do_something_else()
# else:
#     do_another_thing()
#
#
# ````
# ## What is a condition?
# Some examples:
#
# ````
# a > b
# a != b
# (a and b) or (c and d)
# a
# not a
# ````

# %% [markdown]
# ## Iterables and protocols
#
# ````
# for thing in iterable:
#     do_with(thing)
# ````
#
# Protocol:
#
# very general construct because it does not require some specific iterable, but any object that speaks this protocol.

# %% [markdown]
# ### Some examples

# %%
iterable = [1,2,3,4,]

for thing in iterable:
    print(thing)
# Out:
# 1
# 2
# 3
# 4

# %%
# This command is reproducible

for thing in iterable:
    print(thing)
# Out:
# 1
# 2
# 3
# 4

# %%
# This only prints the last thing

print(thing)
# Out:
# 4

# %%
type(iterable)
# Out:
# list

# %%
# This also works for strings

iterable = "Lorem ipsum"

type(iterable)
# Out:
# str

# %%
for thing in iterable:
    print(thing)
# Out:
# L
# o
# r
# e
# m
#
# i
# p
# s
# u
# m

# %%
# Let's make the output look different

for thing in iterable:
    print(f"'{thing}', ", end='')
# Out:
# 'L', 'o', 'r', 'e', 'm', ' ', 'i', 'p', 's', 'u', 'm',

# %%
# A generator object that we can use like an iterable

from pathlib import Path
files = Path('.').glob('*.csv')
print(files)
# Out:
# <map object at 0x103d35fc0>

# %%
# Now iterate

for file in files:
    print(file)
# Out:
# Norvaska.csv
# Santorvia.csv
# Algerra.csv
# Ivoria.csv
# Brunovia.csv
# Belmara.csv
# Elandia.csv
# Cyrdania.csv
# Montabria.csv
# Kaslovia.csv
# Serbeka.csv
# Lazkova.csv
# Marensia.csv

# %%
# Aha! It behaves like an iterable, but it's a one-time generator.

for file in files:
    print(file)

# here I need to know that I can loop just once over this iterable and not twice
# for file in files:  # works
# for file in files:  # produces nothing (empty)

# %%
# Another generator as an example

def generator():
    iterable = [1,2,3,4]
    for value in iterable:
        yield value #yield makes this a generator function so it doesn't return all at once it returns one at a time
    # when called it returns a generator object

g = generator()

print(g)
#here   print(g) #shows that it's a generator object since it uses yield so it doesn't 
# run yet with the iterable values until we loop over it again
# Out:
# <generator object generator at 0x10396bf40>

# %%
# Aha!
for thing in g:
    print(thing) #here you see
# Out:
# 1
# 2
# 3
# 4

# %%
for thing in g:
    print(thing)
    #you can only loop once over a generator since it yields one at a time so here nothing prints

# %%
# while is a bit more basic than for


# while condition:
#    do_something()
    
i = 0
while i < 5:
    print(f'{i}')
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Defining functions

# %%
def my_function(my_parameter):
    print(my_parameter)

my_function(12)
# Out:
# 12

# %%
my_function("Hello world!")

# %%
my_function(files)

# %%
def my_doubler(my_parameter):
    return 2 * my_parameter

# %%
# Explain this result.
my_doubler(4)

# %%
# Explain this result.
my_doubler("abc")

# %%
# Explain this result.
my_doubler(files)

# %%
# What is a function?
my_function

# %%
type(my_function)

# %%
# In Python everything is an object, including functions.

list_of_functions = [my_function, my_doubler]
list_of_functions

# %%
values = [1,2,3,"abc"]
for value in values:
    for func in list_of_functions:
        return_value = func(value)
        print(return_value)
        print("----")

# %% [markdown]
# # If everything is an object, we can also make our own objects.
# Object-oriented programming emerged as a favored solution in the 1990's. It is easier to have data and operations on data together. This approach is more manageable.
#
# If everything is an object, how do we make one ourselves?
#
# Classes are object templates.
#
# Motivation:
# How would you program an inventory of chemicals?

# %% [markdown]
# ## First, the non-object-oriented approach

# %%
# We start with lists of different attributes:
# CAS numbers, amounts in some predefined units, ID numbers for the inventory...

CASs = ["64-17-5", "67-64-1"]
amounts = [1000, 2000]
stock_num = [1, 2]

# %%
# We can print this collection of lists as an inventory.

for num, amount, CAS in zip(stock_num, amounts, CASs):
    print(f"Stock no: {num}, CAS: {CAS}, Amount: {amount}")

# %%
# What if we want to add material to the inventory?
# How would you define the corresponding functions?

def add(CAS, amount, CASs, amounts):
    pass

def take(CAS, amount, CASs, amounts):
    pass

# %% [markdown]
# This can get unwieldy very quickly.
#
# If you wanted to change this inventory, how would you do it?
#
# Defining a class for the inventory of chemical stocks makes this **much easier** and **modular**.

# %% [markdown]
# ## Now the object-oriented approach

# %%
# We define a class.

class Stock:
    # Class attribute
    num_stocks = 0 
    
    # Initialize the object
    def __init__(self, CAS, amount):
        # instance attributes
        self.CAS = CAS
        self.amount = amount
        
        Stock.num_stocks += 1
        self.number = self.num_stocks
    
    # Defining a function to add to the stock
    def add(self, amount):
        self.amount += amount

    # Defining a function to take from the stock including an error if not enough is available
    def take(self, amount):
        if amount <= self.amount:
            self.amount -= amount
            return amount
        else:
            raise ValueError("Amount exceeds available stock")

    # Function to return a printable representation of the object
    def __repr__(self):
        return f"Stock no: {self.number}, CAS: {self.CAS}, Amount: {self.amount}"

# %%
# Now we generate objects of the Stock class

ethanol = Stock("64-17-5", 2000)
acetone = Stock("67-64-1", 1000)

# %%
# What if we want to add to the stock?

ethanol.add(500)
ethanol

# %%
# Or take from the stock?

ethanol.take(750)

# %%
# Print the inventory

inventory = [ethanol, acetone]

for chemical in inventory:
    print(chemical)

# %%
type(ethanol)

# %%
# What if you try to take more than is in stock?

ethanol.take(10000)

# %% [markdown]
# ## Now you try!
#
# Can you modify the "Stock" class to add the IUPAC name of the chemical?
#
# To add units of mass or volume?
#
# How would you prevent an item in "Stock" from being overwritten?
#
# Try it and then make and modify a small inventory to see how it works.
